# %%
import pandas as pd

# %%
path_sam = "/home/owkin/project/experiments/sam/sam_gt_tiles_05_04.csv"

df_metrics_sam = pd.read_csv(path_sam)

df_metrics_sam = df_metrics_sam.rename(columns={"Unnamed: 0": "tile_id"})

# %%
df_metrics_sam
# Out:
#     tile_id  ensemble_dice  IoUByInstance_all_classes  IoUByInstance_class_2  \
# 0   3521541       0.502790                   0.718588               0.718588
# 1   6619042       0.517792                   0.648351               0.648351
# 2  65331257       0.560320                   0.716130               0.716130
# 3  67912873       0.593469                   0.723965               0.723965
# 4  84715806       0.612138                   0.634156               0.634156
# 5  96202074       0.104325                   0.653210               0.653210
#
#          dq     tp    fp        pq        sq    fn
# 0  0.776978  108.0  31.0  0.615768  0.792517  31.0
# 1  0.613065  122.0  77.0  0.474640  0.774208  77.0
# 2  0.829787   39.0   8.0  0.661970  0.797758   8.0
# 3  0.776398  125.0  36.0  0.618902  0.797146  36.0
# 4  0.677778   61.0  29.0  0.494185  0.729126  29.0
# 5  0.617978  110.0  68.0  0.469528  0.759782  68.0

# %%
df_metrics_sam[["ensemble_dice", "IoUByInstance_all_classes", "fn", "dq", "sq", "tp", "pq", "fp"]].mean()
# Out:
# ensemble_dice                 0.481806
# IoUByInstance_all_classes     0.682400
# fn                           41.500000
# dq                            0.715331
# sq                            0.775089
# tp                           94.166667
# pq                            0.555832
# fp                           41.500000
# dtype: float64

# %%
path_nuclick = "/home/owkin/project/experiments/nuclick/test_on_ground_truth_tiles/metrics_per_tile.csv"

df_metrics_nuclick = pd.read_csv(path_nuclick)

df_metrics_nuclick = df_metrics_nuclick.rename(columns={"Unnamed: 0": "tile_id"})

# %%
df_metrics_nuclick
# Out:
#     tile_id  location_id                           coords  \
# 0   3521541     61620116   ((8512, 27776), 0, (448, 448))
# 1   6619042     30647803  ((23744, 33152), 0, (448, 448))
# 2  65331257     13867410   ((7616, 47040), 0, (448, 448))
# 3  67912873     52453855  ((37632, 66304), 0, (448, 448))
# 4  84715806     50554353   ((9856, 18816), 0, (448, 448))
# 5  96202074     95145984  ((90496, 52864), 0, (448, 448))
#
#                                           slide_name  \
# 0  TCGA-G8-6907-01Z-00-DX1.71ada905-9b5b-4757-8df...
# 1  TCGA-FA-A6HO-01Z-00-DX1.9E6256E7-5C4A-4D57-981...
# 2  TCGA-UT-A88E-01Z-00-DX3.B727FAE0-4562-4976-A89...
# 3  TCGA-LK-A4NZ-01Z-00-DX1.8A842571-2333-4957-A88...
# 4  TCGA-C4-A0F6-01Z-00-DX1.05FAB26A-4BE9-42B4-95F...
# 5  TCGA-CU-A3QU-01Z-00-DX1.661F12B3-2865-468B-828...
#
#                                    abstra_slide_path cytomine_username  \
# 0  /home/owkin/data/TCGA_DLBC/histology/raw/paraf...          kvonloga
# ...

# %%
df_metrics_nuclick[["ensemble_dice", "IoUByInstance_all_classes", "fn", "dq", "sq", "tp", "pq", "fp"]].mean()
# Out:
# ensemble_dice                  0.727058
# IoUByInstance_all_classes      0.754638
# fn                            21.000000
# dq                             0.857088
# sq                             0.775044
# tp                           114.666667
# pq                             0.665002
# fp                            21.000000
# dtype: float64
